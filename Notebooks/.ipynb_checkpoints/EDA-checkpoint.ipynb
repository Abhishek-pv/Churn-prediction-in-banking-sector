# %%
# %run ./data_load.ipynb

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
matplotlib.rcParams['figure.figsize'] = (5, 5)

# %%
#printing dimensions of the data
raw_data.shape
# Out:
# (10000, 14)

# %%
#printing columns.
raw_data.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
#removing variables 'RowNumber', 'CustomerId', 'Surname'
raw_data = raw_data.drop(['RowNumber', 'CustomerId', 'Surname'], axis = 1)

# %%
#check for null values in the dataframe
raw_data.isnull().sum()
# Out:
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
#check for NAN values
raw_data.isna().sum()
# Out:
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
#check the distribution of data 
hist = raw_data.hist(bins = 5)

# %% [markdown]
# From the above graphs following are the observations:
# 1. ages: range(20-80)
# 2. IsActiveMember: have binary value 0 and 1
# 3. Exited: target variable where classes = 0 and 1 and seems like it is not balanced.
# 4. HasCrCard: have binary vales 0 and 1

# %%
#checking statistics
raw_data.describe()
# Out:
#         CreditScore           Age        Tenure        Balance  NumOfProducts  \
# count  10000.000000  10000.000000  10000.000000   10000.000000   10000.000000
# mean     650.528800     38.921800      5.012800   76485.889288       1.530200
# std       96.653299     10.487806      2.892174   62397.405202       0.581654
# min      350.000000     18.000000      0.000000       0.000000       1.000000
# 25%      584.000000     32.000000      3.000000       0.000000       1.000000
# 50%      652.000000     37.000000      5.000000   97198.540000       1.000000
# 75%      718.000000     44.000000      7.000000  127644.240000       2.000000
# max      850.000000     92.000000     10.000000  250898.090000       4.000000
#
#          HasCrCard  IsActiveMember  EstimatedSalary        Exited
# count  10000.00000    10000.000000     10000.000000  10000.000000
# mean       0.70550        0.515100    100090.239881      0.203700
# std        0.45584        0.499797     57510.492818      0.402769
# ...

# %%
raw_data.columns
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited'],
#       dtype='object')

# %%
#Checking for outliers.
for column in raw_data:
    if column not in ['Geography', 'Gender']:
        plt.figure()
        raw_data.boxplot([column])

# %% [markdown]
# #couldn't find any outliers.

# %%
#analysis of reponse values.
labels = 'Exited', 'Retained'
sizes = [raw_data.Exited[raw_data['Exited']==1].count(), raw_data.Exited[raw_data['Exited']==0].count()]
explode = (0, 0.1)
fig1, ax1 = plt.subplots(figsize=(10, 8))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')
plt.title("Proportion of customer churned and retained", size = 20)
plt.show()

# %% [markdown]
# #The above plot clearly indicate that this is a imbalanced dataset. So the right metric here is to be F1 score.

# %% [markdown]
# #There is no highly correlated explanatory variables
